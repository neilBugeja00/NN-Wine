# %%
#imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read data
red = pd.read_csv('winequality-red.csv', delimiter = ';')
white = pd.read_csv('winequality-white.csv', delimiter = ';')

# %%
#Displaying data from red db
#Using seaborn to display the data
dims = (11.7,8.27)
fig,ax = plt.subplots(figsize=dims)
CorMap = sns.heatmap(red.corr(), annot = True,fmt= '.1f', ax=ax)
plt.title('Red Wine Correlation')
# Out:
# Text(0.5, 1.0, 'Red Wine Correlation')

# %%
#Red Wine Display Quality Bar Chart
no_class = pd.value_counts(red['quality']).sort_index()
print(no_class)
plt.bar(no_class.index, no_class, align = 'center')
plt.xticks(no_class.index)
plt.title('Red Wine Quality')
# Out:
# 3     10
# 4     53
# 5    681
# 6    638
# 7    199
# 8     18
# Name: quality, dtype: int64
# Text(0.5, 1.0, 'Red Wine Quality')

# %%
#Displaying data from white db
#Using seaborn to display the data
dims = (11.7,8.27)
fig,ax = plt.subplots(figsize=dims)
CorMap = sns.heatmap(white.corr(), annot = True,fmt= '.1f', ax=ax)
plt.title('White Wine Correlation')
# Out:
# Text(0.5, 1.0, 'White Wine Correlation')

# %%
#White Wine Display Quality Bar Chart
no_class = pd.value_counts(white['quality']).sort_index()
print(no_class)
plt.bar(no_class.index, no_class, align = 'center')
plt.xticks(no_class.index)
plt.title('White Wine Quality')
# Out:
# 3      20
# 4     163
# 5    1457
# 6    2198
# 7     880
# 8     175
# 9       5
# Name: quality, dtype: int64
# Text(0.5, 1.0, 'White Wine Quality')

# %%
#Merge databases
red['type'] = 0
white['type'] = 1

wines = red.merge(white, how='outer')

# %%
#Display database as table
wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.4              0.70         0.00             1.9      0.076
# 2               7.8              0.88         0.00             2.6      0.098
# 3               7.8              0.76         0.04             2.3      0.092
# 4              11.2              0.28         0.56             1.9      0.075
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    11.0                  34.0  0.99780  3.51       0.56
# 2                    25.0                  67.0  0.99680  3.20       0.68
# 3                    15.0                  54.0  0.99700  3.26       0.65
# 4                    17.0                  60.0  0.99800  3.16       0.58
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  type
# 0         9.4        5     0
# 1         9.4        5     0
# 2         9.8        5     0
# 3         9.8        5     0
# 4         9.8        6     0
# ...       ...      ...   ...
# 6492     11.2        6     1
# 6493      9.6        5     1
# 6494      9.4        6     1
# 6495     12.8        7     1
# 6496     11.8        6     1
#
# [6497 rows x 13 columns]
